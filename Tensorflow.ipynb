# %%
from IPython.display import clear_output
from six.moves import urllib
import tensorflow as tf

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import tensorflow.compat.v2.feature_column as fc

# %%
dftrain = pd.read_csv("F:/This Semester/Machine Learning/Machine Learning/Machine Learning Datasets/titanic/train.csv")
dftest = pd.read_csv("F:/This Semester/Machine Learning/Machine Learning/Machine Learning Datasets/titanic/test.csv")
dftest1 = pd.read_csv("F:/This Semester/Machine Learning/Machine Learning/Machine Learning Datasets/titanic/gender_submission.csv")
y_train =dftrain.pop('Survived')
y_test = dftest1.pop('Survived')

# %%
dftrain.head(50)
#dftrain.Age.hist(bins=20)
# Out:
#     PassengerId Embarked  Pclass  \
# 0             1        S       3
# 1             2        C       1
# 2             3        S       3
# 3             4        S       1
# 4             5        S       3
# 5             6        Q       3
# 6             7        S       1
# 7             8        S       3
# 8             9        S       3
# 9            10        C       2
# 10           11        S       3
# 11           12        S       1
# 12           13        S       3
# 13           14        S       3
# 14           15        S       3
# 15           16        S       2
# 16           17        Q       3
# 17           18        S       2
# 18           19        S       3
# 19           20        C       3
# 20           21        S       2
# 21           22        S       2
# 22           23        Q       3
# 23           24        S       1
# 24           25        S       3
# 25           26        S       3
# 26           27        C       3
# ...

# %%
Categorical_columns = ['Embarked','Cabin','Sex','Pclass']
Numerical_columns = ['Age','Fare','Sibsp']
feature_columns = []
for feature_name in Categorical_columns:
    vocabulary =dftrain[feature_name].unique()
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name,vocabulary))
    
for feature_name in Numerical_columns:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))
    
print(feature_columns)
# Out:
# [VocabularyListCategoricalColumn(key='Embarked', vocabulary_list=('S', 'C', 'Q', nan), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='Cabin', vocabulary_list=(nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19', 'D50', 'D9', 'A2
# ...
